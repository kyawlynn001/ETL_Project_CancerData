# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from pymongo import MongoClient

# %%
cancer_to_load = "./Resources/BreastCancerResearch.csv"
breast_cancer = pd.read_csv(cancer_to_load, delimiter=',')
breast_cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast_cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
breast_cancer_dropna = breast_cancer.dropna()
breast_cancer_selection = breast_cancer[["id", "diagnosis","radius_mean","perimeter_worst","radius_worst","symmetry_worst"]]
breast_cancer_selection.head()
# Out:
#          id diagnosis  radius_mean  perimeter_worst  radius_worst  \
# 0    842302         M        17.99           184.60         25.38
# 1    842517         M        20.57           158.80         24.99
# 2  84300903         M        19.69           152.50         23.57
# 3  84348301         M        11.42            98.87         14.91
# 4  84358402         M        20.29           152.20         22.54
#
#    symmetry_worst
# 0          0.4601
# 1          0.2750
# 2          0.3613
# 3          0.6638
# 4          0.2364

# %%
#Use Dictionay method due to json limitation 
data = breast_cancer_selection.to_dict('records')
# cancer = json.loads(data)
# print(cancer)

# %%
# !pip install pymongo

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
from pymongo import MongoClient

# %%
#initialize Pymongo to work with Mongo
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
#Define database and collecton 
db = client["cancer_db"]
breastcancer = db["cancer"]

# %%
breastcancer.insert_many(data)

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [{'id': 842302,
#   'diagnosis': 'M',
#   'radius_mean': 17.99,
#   'perimeter_worst': 184.6,
#   'radius_worst': 25.38,
#   'symmetry_worst': 0.4601,
#   '_id': ObjectId('5e55b94a9d970ff9b700d92c')},
#  {'id': 842517,
#   'diagnosis': 'M',
#   'radius_mean': 20.57,
#   'perimeter_worst': 158.8,
#   'radius_worst': 24.99,
#   'symmetry_worst': 0.275,
#   '_id': ObjectId('5e55b94a9d970ff9b700d92d')},
#  {'id': 84300903,
#   'diagnosis': 'M',
#   'radius_mean': 19.69,
#   'perimeter_worst': 152.5,
#   'radius_worst': 23.57,
#   'symmetry_worst': 0.3613,
#   '_id': ObjectId('5e55b94a9d970ff9b700d92e')},
#  {'id': 84348301,
#   'diagnosis': 'M',
#   'radius_mean': 11.42,
#   'perimeter_worst': 98.87,
#   'radius_worst': 14.91,
#   'symmetry_worst': 0.6638,
#   '_id': ObjectId('5e55b94a9d970ff9b700d92f')},
#  {'id': 84358402,
#   'diagnosis': 'M',
#   'radius_mean': 20.29,
#   'perimeter_worst': 152.2,
#   'radius_worst': 22.54,
#   'symmetry_worst': 0.2364,
# ...

# %%
for i in data:
    print(type(i))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...

# %%
# Display the MongoDB records created above
db = db.data.find()
for i in data:
    print(i)
# Out:
# {'id': 842302, 'diagnosis': 'M', 'radius_mean': 17.99, 'perimeter_worst': 184.6, 'radius_worst': 25.38, 'symmetry_worst': 0.4601, '_id': ObjectId('5e55b94a9d970ff9b700d92c')}
# {'id': 842517, 'diagnosis': 'M', 'radius_mean': 20.57, 'perimeter_worst': 158.8, 'radius_worst': 24.99, 'symmetry_worst': 0.275, '_id': ObjectId('5e55b94a9d970ff9b700d92d')}
# {'id': 84300903, 'diagnosis': 'M', 'radius_mean': 19.69, 'perimeter_worst': 152.5, 'radius_worst': 23.57, 'symmetry_worst': 0.3613, '_id': ObjectId('5e55b94a9d970ff9b700d92e')}
# {'id': 84348301, 'diagnosis': 'M', 'radius_mean': 11.42, 'perimeter_worst': 98.87, 'radius_worst': 14.91, 'symmetry_worst': 0.6638, '_id': ObjectId('5e55b94a9d970ff9b700d92f')}
# {'id': 84358402, 'diagnosis': 'M', 'radius_mean': 20.29, 'perimeter_worst': 152.2, 'radius_worst': 22.54, 'symmetry_worst': 0.2364, '_id': ObjectId('5e55b94a9d970ff9b700d930')}
# ...
